# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import sklearn
print("Numpy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", plt.matplotlib.__version__)
print("Seaborn:", sns.__version__)
print("TensorFlow:", tf.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# Numpy: 2.3.3
# Pandas: 2.3.2
# Matplotlib: 3.10.6
# Seaborn: 0.13.2
# TensorFlow: 2.20.0
# Scikit-learn: 1.7.2

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
# Importing essential libraries for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,8))
sns.countplot(x='Exited', data=df)
plt.xlabel('0: Customers still with the bank, 1: Customers exited the bank')
plt.ylabel('Count')
plt.title('Bank Customers Churn Visualization')
plt.show()

# %%
df.isna().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df.drop(['RowNumber','CustomerId','Surname'], axis=1, inplace=True)
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
# Converting 'Geography' and 'Gender' column
geography = pd.get_dummies(df['Geography'], drop_first=True)
gender = pd.get_dummies(df['Gender'], drop_first=True)

# %%
# Appending columns to original dataframe
df = pd.concat([df, geography, gender], axis=1)
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Germany', 'Spain', 'Male'],
#       dtype='object')

# %%
df.drop(['Geography', 'Gender'], axis=1, inplace=True)

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
# Splitting the dataset into train and test sets.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print('X_train size: {}, X_test size: {}'.format(X_train.shape, X_test.shape))
# Out:
# X_train size: (8000, 11), X_test size: (2000, 11)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units=6, 
                     kernel_initializer='he_uniform', 
                     activation='relu', 
                     input_dim=X_train.shape[1]))
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Adding the second hidden layer
classifier.add(Dense(units=6, 
                     kernel_initializer='he_uniform', 
                     activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(units=1, 
                     kernel_initializer='glorot_uniform', 
                     activation='sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer='adam', 
                   loss='binary_crossentropy', 
                   metrics=['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history = classifier.fit(X_train, y_train, 
                               batch_size=10, 
                               epochs=100, 
                               validation_split=0.2)
# Out:
# Epoch 1/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7709 - loss: 0.5568 - val_accuracy: 0.8044 - val_loss: 0.4816
# Epoch 2/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8047 - loss: 0.4629 - val_accuracy: 0.8188 - val_loss: 0.4372
# Epoch 3/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8102 - loss: 0.4413 - val_accuracy: 0.8250 - val_loss: 0.4248
# Epoch 4/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8145 - loss: 0.4327 - val_accuracy: 0.8244 - val_loss: 0.4188
# Epoch 5/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8203 - loss: 0.4268 - val_accuracy: 0.8269 - val_loss: 0.4140
# Epoch 6/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8230 - loss: 0.4217 - val_accuracy: 0.8300 - val_loss: 0.4111
# Epoch 7/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8250 - loss: 0.4173 - val_accuracy: 0.8313 - val_loss: 0.4074
# Epoch 8/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8284 - loss: 0.4130 - val_accuracy: 0.8344 - val_loss: 0.4047
# Epoch 9/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8295 - loss: 0.4080 - val_accuracy: 0.8375 - val_loss: 0.4010
# Epoch 10/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8342 - loss: 0.4028 - val_accuracy: 0.8425 - val_loss: 0.3965
# Epoch 11/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8372 - loss: 0.3963 - val_accuracy: 0.8475 - val_loss: 0.3897
# Epoch 12/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8430 - loss: 0.3870 - val_accuracy: 0.8487 - val_loss: 0.3816
# Epoch 13/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8486 - loss: 0.3755 - val_accuracy: 0.8494 - val_loss: 0.3732
# Epoch 14/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8536 - loss: 0.3641 - val_accuracy: 0.8550 - val_loss: 0.3644
# Epoch 15/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8547 - loss: 0.3550 - val_accuracy: 0.8525 - val_loss: 0.3574
# Epoch 16/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8572 - loss: 0.3489 - val_accuracy: 0.8562 - val_loss: 0.3533
# Epoch 17/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8598 - loss: 0.3450 - val_accuracy: 0.8587 - val_loss: 0.3500
# Epoch 18/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8605 - loss: 0.3426 - val_accuracy: 0.8594 - val_loss: 0.3486
# Epoch 19/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8609 - loss: 0.3402 - val_accuracy: 0.8550 - val_loss: 0.3491
# Epoch 20/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8606 - loss: 0.3397 - val_accuracy: 0.8575 - val_loss: 0.3473
# Epoch 21/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8623 - loss: 0.3388 - val_accuracy: 0.8575 - val_loss: 0.3456
# Epoch 22/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8623 - loss: 0.3374 - val_accuracy: 0.8531 - val_loss: 0.3452
# Epoch 23/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8611 - loss: 0.3373 - val_accuracy: 0.8575 - val_loss: 0.3442
# Epoch 24/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8627 - loss: 0.3365 - val_accuracy: 0.8575 - val_loss: 0.3445
# Epoch 25/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8625 - loss: 0.3363 - val_accuracy: 0.8550 - val_loss: 0.3434
# Epoch 26/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8627 - loss: 0.3362 - val_accuracy: 0.8556 - val_loss: 0.3435
# Epoch 27/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8631 - loss: 0.3347 - val_accuracy: 0.8556 - val_loss: 0.3456
# Epoch 28/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8612 - loss: 0.3352 - val_accuracy: 0.8562 - val_loss: 0.3432
# Epoch 29/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8639 - loss: 0.3351 - val_accuracy: 0.8569 - val_loss: 0.3443
# Epoch 30/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8614 - loss: 0.3343 - val_accuracy: 0.8525 - val_loss: 0.3435
# Epoch 31/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8628 - loss: 0.3341 - val_accuracy: 0.8550 - val_loss: 0.3425
# Epoch 32/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8619 - loss: 0.3341 - val_accuracy: 0.8544 - val_loss: 0.3429
# Epoch 33/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8642 - loss: 0.3338 - val_accuracy: 0.8544 - val_loss: 0.3426
# Epoch 34/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8617 - loss: 0.3334 - val_accuracy: 0.8556 - val_loss: 0.3416
# Epoch 35/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8623 - loss: 0.3331 - val_accuracy: 0.8569 - val_loss: 0.3425
# Epoch 36/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8595 - loss: 0.3332 - val_accuracy: 0.8581 - val_loss: 0.3421
# Epoch 37/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8636 - loss: 0.3327 - val_accuracy: 0.8594 - val_loss: 0.3431
# Epoch 38/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8634 - loss: 0.3323 - val_accuracy: 0.8569 - val_loss: 0.3433
# Epoch 39/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8637 - loss: 0.3329 - val_accuracy: 0.8544 - val_loss: 0.3420
# Epoch 40/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8628 - loss: 0.3323 - val_accuracy: 0.8550 - val_loss: 0.3419
# Epoch 41/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8636 - loss: 0.3323 - val_accuracy: 0.8575 - val_loss: 0.3413
# Epoch 42/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8623 - loss: 0.3324 - val_accuracy: 0.8556 - val_loss: 0.3406
# Epoch 43/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8631 - loss: 0.3325 - val_accuracy: 0.8562 - val_loss: 0.3416
# Epoch 44/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8631 - loss: 0.3315 - val_accuracy: 0.8550 - val_loss: 0.3409
# Epoch 45/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8631 - loss: 0.3321 - val_accuracy: 0.8600 - val_loss: 0.3410
# Epoch 46/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8647 - loss: 0.3317 - val_accuracy: 0.8625 - val_loss: 0.3432
# Epoch 47/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8634 - loss: 0.3314 - val_accuracy: 0.8569 - val_loss: 0.3413
# Epoch 48/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8630 - loss: 0.3315 - val_accuracy: 0.8594 - val_loss: 0.3415
# Epoch 49/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8633 - loss: 0.3318 - val_accuracy: 0.8587 - val_loss: 0.3406
# Epoch 50/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8644 - loss: 0.3317 - val_accuracy: 0.8594 - val_loss: 0.3421
# Epoch 51/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8630 - loss: 0.3313 - val_accuracy: 0.8556 - val_loss: 0.3414
# Epoch 52/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8630 - loss: 0.3311 - val_accuracy: 0.8550 - val_loss: 0.3411
# Epoch 53/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8612 - loss: 0.3315 - val_accuracy: 0.8612 - val_loss: 0.3408
# Epoch 54/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8628 - loss: 0.3312 - val_accuracy: 0.8562 - val_loss: 0.3411
# Epoch 55/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8650 - loss: 0.3307 - val_accuracy: 0.8556 - val_loss: 0.3411
# Epoch 56/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8641 - loss: 0.3309 - val_accuracy: 0.8531 - val_loss: 0.3416
# Epoch 57/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8639 - loss: 0.3313 - val_accuracy: 0.8581 - val_loss: 0.3409
# Epoch 58/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8617 - loss: 0.3311 - val_accuracy: 0.8569 - val_loss: 0.3414
# Epoch 59/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8642 - loss: 0.3301 - val_accuracy: 0.8556 - val_loss: 0.3416
# Epoch 60/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8652 - loss: 0.3309 - val_accuracy: 0.8594 - val_loss: 0.3411
# Epoch 61/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8650 - loss: 0.3308 - val_accuracy: 0.8544 - val_loss: 0.3407
# Epoch 62/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8636 - loss: 0.3306 - val_accuracy: 0.8600 - val_loss: 0.3412
# Epoch 63/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8647 - loss: 0.3307 - val_accuracy: 0.8569 - val_loss: 0.3405
# Epoch 64/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8641 - loss: 0.3309 - val_accuracy: 0.8550 - val_loss: 0.3400
# Epoch 65/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8658 - loss: 0.3302 - val_accuracy: 0.8581 - val_loss: 0.3407
# Epoch 66/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8650 - loss: 0.3302 - val_accuracy: 0.8556 - val_loss: 0.3405
# Epoch 67/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8648 - loss: 0.3302 - val_accuracy: 0.8606 - val_loss: 0.3393
# Epoch 68/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8650 - loss: 0.3297 - val_accuracy: 0.8581 - val_loss: 0.3402
# Epoch 69/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8648 - loss: 0.3301 - val_accuracy: 0.8587 - val_loss: 0.3391
# Epoch 70/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8650 - loss: 0.3303 - val_accuracy: 0.8581 - val_loss: 0.3400
# Epoch 71/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8650 - loss: 0.3299 - val_accuracy: 0.8575 - val_loss: 0.3395
# Epoch 72/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8664 - loss: 0.3297 - val_accuracy: 0.8550 - val_loss: 0.3401
# Epoch 73/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8645 - loss: 0.3297 - val_accuracy: 0.8606 - val_loss: 0.3397
# Epoch 74/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8670 - loss: 0.3299 - val_accuracy: 0.8556 - val_loss: 0.3395
# Epoch 75/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8642 - loss: 0.3299 - val_accuracy: 0.8619 - val_loss: 0.3404
# Epoch 76/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8645 - loss: 0.3295 - val_accuracy: 0.8569 - val_loss: 0.3409
# Epoch 77/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8650 - loss: 0.3296 - val_accuracy: 0.8537 - val_loss: 0.3414
# Epoch 78/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8645 - loss: 0.3301 - val_accuracy: 0.8537 - val_loss: 0.3401
# Epoch 79/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8647 - loss: 0.3297 - val_accuracy: 0.8606 - val_loss: 0.3403
# Epoch 80/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8656 - loss: 0.3291 - val_accuracy: 0.8562 - val_loss: 0.3406
# Epoch 81/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8669 - loss: 0.3295 - val_accuracy: 0.8612 - val_loss: 0.3409
# Epoch 82/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8645 - loss: 0.3296 - val_accuracy: 0.8550 - val_loss: 0.3399
# Epoch 83/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8645 - loss: 0.3290 - val_accuracy: 0.8631 - val_loss: 0.3435
# Epoch 84/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8639 - loss: 0.3300 - val_accuracy: 0.8612 - val_loss: 0.3412
# Epoch 85/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8664 - loss: 0.3295 - val_accuracy: 0.8550 - val_loss: 0.3398
# Epoch 86/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8653 - loss: 0.3293 - val_accuracy: 0.8631 - val_loss: 0.3396
# Epoch 87/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8644 - loss: 0.3290 - val_accuracy: 0.8581 - val_loss: 0.3401
# Epoch 88/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8677 - loss: 0.3287 - val_accuracy: 0.8581 - val_loss: 0.3417
# Epoch 89/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8652 - loss: 0.3295 - val_accuracy: 0.8569 - val_loss: 0.3409
# Epoch 90/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8639 - loss: 0.3294 - val_accuracy: 0.8575 - val_loss: 0.3405
# Epoch 91/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8661 - loss: 0.3293 - val_accuracy: 0.8581 - val_loss: 0.3398
# Epoch 92/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8662 - loss: 0.3290 - val_accuracy: 0.8612 - val_loss: 0.3418
# Epoch 93/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8661 - loss: 0.3295 - val_accuracy: 0.8581 - val_loss: 0.3410
# Epoch 94/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8659 - loss: 0.3289 - val_accuracy: 0.8594 - val_loss: 0.3414
# Epoch 95/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8652 - loss: 0.3289 - val_accuracy: 0.8612 - val_loss: 0.3411
# Epoch 96/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8648 - loss: 0.3288 - val_accuracy: 0.8619 - val_loss: 0.3424
# Epoch 97/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8680 - loss: 0.3291 - val_accuracy: 0.8581 - val_loss: 0.3399
# Epoch 98/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8666 - loss: 0.3284 - val_accuracy: 0.8544 - val_loss: 0.3413
# Epoch 99/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8677 - loss: 0.3287 - val_accuracy: 0.8575 - val_loss: 0.3407
# Epoch 100/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8666 - loss: 0.3284 - val_accuracy: 0.8531 - val_loss: 0.3423

# %%
# List all data in history
model_history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Summarize history for accuracy
plt.figure(figsize=(8,8))
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# %%
# Summarize history for loss
plt.figure(figsize=(8,8))
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_pred
# Out:
# array([[0.04797945],
#        [0.02855948],
#        [0.10999542],
#        ...,
#        [0.77350044],
#        [0.10728462],
#        [0.33063108]], shape=(2000, 1), dtype=float32)

# %%
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]], shape=(2000, 1))

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1514,   93],
#        [ 195,  198]])

# %%
# Plotting confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm, cmap='Blues', annot=True,  
            xticklabels=['Did not Exit', 'Exited'], 
            yticklabels=['Did not Exit', 'Exited'])
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.title('Confusion Matrix for ANN model')
plt.show()

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
print('The accuracy for ANN model is: {}%'.format(score*100))
# Out:
# The accuracy for ANN model is: 85.6%

# %%
def predict_exit(sample_value):

 # Convert list to numpy array
 sample_value = np.array(sample_value)
 # Reshape because sample_value contains only 1 record
 sample_value = sample_value.reshape(1, -1)
 # Feature Scaling
 sample_value = sc.transform(sample_value)
 return classifier.predict(sample_value)

# %%
# Predictions
sample_value = [738, 62, 10, 83008.31, 1, 1, 1, 42766.03, 1, 0, 1]
if predict_exit(sample_value)>0.5:
 print('Prediction: High change of exit!')
else:
 print('Prediction: Low change of exit.')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Prediction: Low change of exit.
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Predictions
sample_value = [805, 45, 9, 116585.97, 1, 1, 0, 189428.75, 1, 0, 0]
if predict_exit(sample_value)>0.5:
 print('Prediction: High change of exit!')
else:
 print('Prediction: Low change of exit.')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Prediction: High change of exit!
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
